# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from DataSetFactory import DataSetFactory
from AMAP import AMAP

# %%
RANDOM_STATE = 42

# %%
ds = DataSetFactory.get_dataset('FashionMNIST64', random_state=RANDOM_STATE, is_subset=True, sample=0.15)
# Out:
# Taking sample of 0.15 from the data

# %%
X = ds.df[ds.feature_cols].values
y = ds.df[ds.label_col].values

# %% [markdown]
# # PCA

# %%
amap = AMAP(dim_reduction_algo='pca',
            reduce_all_points=True,
            n_iter=1, 
            batch_size=0,
            learning_rate=0.1,
            do_animation=False,
            dataset='FashionMNIST',
            class_to_label=ds.class_to_label,
            show_fig=True,
            save_fig=True,
            random_state=RANDOM_STATE,
            show_anchors=False,
            supervised=False,
            show_points=True,
            show_inner_blobs=False,
            show_polygons=False,
            show_label_level_plots=False,
            show_anchor_level_plot=False,
            annotate_images=False)
print(amap)
# Out:
# AMAP
# =================
# addr:@458808
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=0.3
# birch_branching_factor=None
# dim_reduction_algo='pca'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=True
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=1
# magnitude_step=False
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x000002629C454DC8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.1
# mask_sparse_subcluster=None
# random_points_method='voronoi'
# class_to_label={0: 'Trouser', 1: 'Sandal', 2: 'Sneaker', 3: 'Ankle boot'}
# random_state=42
# n_jobs=None
# dataset='FashionMNIST'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=None
# douglas_peucker_tolerance=0.6
# smooth_iter=13
# show_relations=False
# mask_relation_in_same_label=False
# save_fig_every=1
# show_points=True
# show_anchors=False
# show_polygons=False
# show_inner_blobs=False
# alpha_voronoi=False
# show_label_level_plots=False
# show_anchor_level_plot=False
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# annotate_images=False
# orig_images=None
# output_dir='./plots/FashionMNIST/2020-20-03_13-54-25/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
pca_low_dim = amap.fit_transform(X, y)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction all points
# Starting iteration 1 loss = 0.631578947368421

# %% [markdown]
# # UMAP

# %%
umap_amap = AMAP(dim_reduction_algo='umap',
            reduce_all_points=True,
            n_iter=1, 
            batch_size=0,
            learning_rate=0.1,
            do_animation=False,
            dataset='FashionMNIST',
            class_to_label=ds.class_to_label,
            show_fig=True,
            save_fig=True,
            random_state=RANDOM_STATE,
            show_anchors=False,
            supervised=True,
            show_points=True,
            show_inner_blobs=False,
            show_polygons=False,
            show_label_level_plots=False,
            show_anchor_level_plot=False,
            annotate_images=False)
print(umap_amap)
# Out:
# AMAP
# =================
# addr:@985dc8
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=0.3
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=True
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=True
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=1
# magnitude_step=False
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x000002629C454DC8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.1
# mask_sparse_subcluster=None
# random_points_method='voronoi'
# class_to_label={0: 'Trouser', 1: 'Sandal', 2: 'Sneaker', 3: 'Ankle boot'}
# random_state=42
# n_jobs=None
# dataset='FashionMNIST'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=None
# douglas_peucker_tolerance=0.6
# smooth_iter=13
# show_relations=False
# mask_relation_in_same_label=False
# save_fig_every=1
# show_points=True
# show_anchors=False
# show_polygons=False
# show_inner_blobs=False
# alpha_voronoi=False
# show_label_level_plots=False
# show_anchor_level_plot=False
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# annotate_images=False
# orig_images=None
# output_dir='./plots/FashionMNIST/2020-20-03_13-54-50/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
umap_low_dim = umap_amap.fit_transform(X, y)
# Out:
# finding intra class anchors using birch
# Supervised Dim Reduction
# Dim Reduction all points
# C:\Users\omalkai\AppData\Local\Continuum\anaconda3_new\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
#
#
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\..\AppData\Local\Continuum\anaconda3_new\lib\site-packages\umap\rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#
# C:\Users\omalkai\AppData\Local\Continuum\anaconda3_new\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
#
#
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\..\AppData\Local\Continuum\anaconda3_new\lib\site-packages\umap\rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#
# C:\Users\omalkai\AppData\Local\Continuum\anaconda3_new\lib\site-packages\umap\nndescent.py:92: NumbaPerformanceWarning:
#
#
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\..\AppData\Local\Continuum\anaconda3_new\lib\site-packages\umap\utils.py", line 409:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#
# C:\Users\omalkai\AppData\Local\Continuum\anaconda3_new\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
#
#
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\..\AppData\Local\Continuum\anaconda3_new\lib\site-packages\umap\nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
# Starting iteration 1 loss = 0.6578947368421053

# %% [markdown]
# # TSNE

# %%
tsne_amap = AMAP(dim_reduction_algo='umap',
            reduce_all_points=True,
            n_iter=1, 
            batch_size=0,
            learning_rate=0.1,
            do_animation=False,
            dataset='FashionMNIST',
            class_to_label=ds.class_to_label,
            show_fig=True,
            save_fig=True,
            random_state=RANDOM_STATE,
            show_anchors=False,
            supervised=False,
            show_points=True,
            show_inner_blobs=False,
            show_polygons=False,
            show_label_level_plots=False,
            show_anchor_level_plot=False,
            annotate_images=False)
print(tsne_amap)
# Out:
# AMAP
# =================
# addr:@c2fc8
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=0.3
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=True
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=1
# magnitude_step=False
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x000002629C454DC8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.1
# mask_sparse_subcluster=None
# random_points_method='voronoi'
# class_to_label={0: 'Trouser', 1: 'Sandal', 2: 'Sneaker', 3: 'Ankle boot'}
# random_state=42
# n_jobs=None
# dataset='FashionMNIST'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=None
# douglas_peucker_tolerance=0.6
# smooth_iter=13
# show_relations=False
# mask_relation_in_same_label=False
# save_fig_every=1
# show_points=True
# show_anchors=False
# show_polygons=False
# show_inner_blobs=False
# alpha_voronoi=False
# show_label_level_plots=False
# show_anchor_level_plot=False
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# annotate_images=False
# orig_images=None
# output_dir='./plots/FashionMNIST/2020-20-03_13-55-33/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
tsne_low_dim = tsne_amap.fit_transform(X, y)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction all points
# C:\Users\omalkai\AppData\Local\Continuum\anaconda3_new\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
#
#
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\..\AppData\Local\Continuum\anaconda3_new\lib\site-packages\umap\nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
# Starting iteration 1 loss = 0.631578947368421

# %% [markdown]
# # Our Blobs No Relaxation

# %%
blobs_amap = AMAP(dim_reduction_algo='umap',
                reduce_all_points=False,
                n_iter=1, 
                batch_size=0,
                learning_rate=0.1,
                do_animation=False,
                dataset='FashionMNIST',
                class_to_label=ds.class_to_label,
                show_fig=True,
                save_fig=True,
                random_state=RANDOM_STATE,
                show_anchors=False,
                supervised=False,
                show_points=False,
                show_inner_blobs=True,
                show_polygons=True,
                show_label_level_plots=False,
                show_anchor_level_plot=False,
                annotate_images=False,
                birch_threshold=0.6,
#                 birch_threshold=1,
#                 alpha=None,
                alpha=0.6,
                douglas_peucker_tolerance=0.3,
                smooth_iter=3,
                only_inter_relations=False,
                mask_relation_in_same_label=True,)
print(blobs_amap)
# Out:
# AMAP
# =================
# addr:@bce3c8
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=0.6
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=False
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=1
# magnitude_step=False
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x000001ACD3B55F78>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.1
# mask_sparse_subcluster=None
# random_points_method='voronoi'
# class_to_label={0: 'Trouser', 1: 'Sandal', 2: 'Sneaker', 3: 'Ankle boot'}
# random_state=42
# n_jobs=None
# dataset='FashionMNIST'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=0.6
# douglas_peucker_tolerance=0.3
# smooth_iter=3
# skip_polygons_with_area=0.01
# show_relations=False
# mask_relation_in_same_label=True
# save_fig_every=1
# show_points=False
# show_anchors=False
# show_polygons=True
# show_inner_blobs=True
# alpha_voronoi=False
# show_label_level_plots=False
# show_anchor_level_plot=False
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# annotate_images=False
# orig_images=None
# output_dir='./plots/FashionMNIST/2020-21-03_15-30-45/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
blobs_low_dim = blobs_amap.fit_transform(X, y)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction only anchors
# Dim Reduction only anchors - generate random points in low dim per anchor
# 100%|█████████████████████████████████████████████████████████████████████████████| 3948/3948 [00:24<00:00, 163.47it/s]
# Starting iteration 1 loss = 0.919780506924484

# %%
blobs_amap.alpha=[0,1.3,0.8,1]
blobs_amap.douglas_peucker_tolerance = 0.3
blobs_amap.skip_polygons_with_area = 0.5
blobs_amap.anchors_plot_sns_separate(1, True)
# Out:
# Skipping polygon of label 1 with area 0.017536377500881883
# Skipping polygon of label 1 with area 0.3120909685168021
# Skipping polygon of label 1 with area 0.00016719116717212046
# Skipping polygon of label 2 with area 0.015698450383008655
# Skipping polygon of label 2 with area 0.0001671871811153025
# Skipping polygon of label 3 with area 0.010491827394151429
# Skipping polygon of label 3 with area 0.0001671871811153025
# Skipping polygon of label 1 with area 0.017536377500881883
# Skipping polygon of label 1 with area 0.3120909685168021
# Skipping polygon of label 1 with area 0.00016719116717212046
# Skipping polygon of label 2 with area 0.015698450383008655
# Skipping polygon of label 2 with area 0.0001671871811153025
# Skipping polygon of label 3 with area 0.010491827394151429
# Skipping polygon of label 3 with area 0.0001671871811153025
