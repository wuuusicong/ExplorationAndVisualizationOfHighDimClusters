# %% [markdown]
# # Imports

# %%
import sys
sys.path.append('../src/')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import joblib
from sklearn.metrics import pairwise_distances
from PIL import Image
from sklearn.metrics import pairwise_distances
from sklearn.cluster import Birch
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

from DataSetFactory import DataSetFactory
from AMAP import AMAP

# %%
RANDOM_STATE = 42

# %%
ds_scaled = DataSetFactory.get_dataset('wine-sklearn-scaled', random_state=RANDOM_STATE)
ds_not_scaled = DataSetFactory.get_dataset('wine-sklearn-not-scaled', random_state=RANDOM_STATE)
# Out:
# using min max scaler
# skip scaling

# %%
X_scaled = ds_scaled.df[ds_scaled.feature_cols].values
y_scaled = ds_scaled.df[ds_scaled.label_col].values

X_not_scaled = ds_not_scaled.df[ds_not_scaled.feature_cols].values
y_not_scaled = ds_not_scaled.df[ds_not_scaled.label_col].values

# %%
X_scaled.shape
X_not_scaled.shape
# Out:
# (178, 13)

# %%
pd.Series(y_scaled).value_counts().sort_index()
# Out:
# 0    59
# 1    71
# 2    48
# dtype: int64

# %% [markdown]
# # Birch Threshold

# %%
def get_num_clusters_birch(ds, threshold):
    num_clusters = 0
    for label in ds.df[ds.label_col].unique():
        label_data = ds.df[ds.df[ds.label_col]==label][ds.feature_cols].values
        birch = Birch(threshold=threshold, branching_factor=2, n_clusters=None)
        birch.fit(label_data)
        num_clusters += birch.subcluster_centers_.shape[0]
    return num_clusters

def birch_threshold_plot(X, scaled, ds):
    dist_mat = pairwise_distances(X)
    print(dist_mat.shape)
    threshold_candidates = np.unique(dist_mat)
    print(threshold_candidates.shape)
    # for the sake of the experiment let's evaluate all of them
    thresholds_df = pd.DataFrame(threshold_candidates, columns=['threshold'])
    thresholds_df['num_clusters'] = np.nan
    thresholds_df['num_points'] = ds.df.shape[0]
    thresholds_df.hist(['threshold'])
    plt.show()
    # Filter only thresholds smaller than 1.5
    if scaled:
        thresholds_df_sample = thresholds_df[thresholds_df['threshold']<=100]
        thresholds_df_sample = thresholds_df_sample.sample(n=200, random_state=RANDOM_STATE)
    else:
        thresholds_df_sample = thresholds_df.sample(n=200)
    
    thresholds_df_sample['num_clusters'] = thresholds_df_sample['threshold'].transform(lambda t: get_num_clusters_birch(ds, t))
    thresholds_df_sample['compression'] = thresholds_df_sample['num_points'] / thresholds_df_sample['num_clusters']
    
    sns.lineplot(x='threshold', y='compression', data=thresholds_df_sample)
    sns.lineplot(x='threshold', y='num_clusters', data=thresholds_df_sample)

# %%
birch_threshold_plot(X_scaled, True, ds_scaled)
# Out:
# (178, 178)
# (16313,)

# %%
birch_threshold_plot(X_not_scaled, True, ds_not_scaled)
# Out:
# (178, 178)
# (20398,)

# %% [markdown]
# # Unsupervised UMAP

# %% [markdown]
# ## Not Scaled

# %%
umap_not_scaled_amap = AMAP(dim_reduction_algo='umap',
            reduce_all_points=True,
            n_iter=1, 
            batch_size=0,
            learning_rate=0.1,
            do_animation=False,
            dataset='Wine',
            class_to_label=ds_not_scaled.class_to_label,
            show_fig=True,
            save_fig=True,
            random_state=RANDOM_STATE,
            show_anchors=False,
            supervised=False,
            show_points=True,
            show_inner_blobs=False,
            show_polygons=False,
            show_label_level_plots=True,
            show_anchor_level_plot=False,
            annotate_images=False,
#             birch_threshold=0.4,  # scaled features
            birch_threshold=20)
print(umap_not_scaled_amap)
# Out:
# AMAP
# =================
# addr:@2de708
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=20
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=True
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=1
# magnitude_step=False
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x0000015A5C8868B8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.1
# mask_sparse_subcluster=None
# random_points_method='voronoi'
# class_to_label={0: 'class_0', 1: 'class_1', 2: 'class_2'}
# random_state=42
# n_jobs=None
# dataset='Wine'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=None
# douglas_peucker_tolerance=0.6
# smooth_iter=3
# skip_polygons_with_area=0.01
# mask_relation_in_same_label=True
# save_fig_every=1
# show_points=True
# show_anchors=False
# show_polygons=False
# show_inner_blobs=False
# show_label_level_plots=True
# show_anchor_level_plot=False
# every_matrix_in_single_plot=True
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# vmax_overlap=0.5
# vmax_proximity=0.5
# annotate_images=False
# k_annot_clf=40
# orig_images=None
# output_dir='../plots/Wine/2020-31-03_01-25-59/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# high_dim_proximity_matrix=None
# low_dim_proximity_matrix=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
low_dim_umap = umap_not_scaled_amap.fit_transform(X_not_scaled, y_not_scaled)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction all points
# Starting iteration 1 loss = 0.21052631578947367

# %% [markdown]
# ## Scaled

# %%
umap_scaled_amap = AMAP(dim_reduction_algo='umap',
            reduce_all_points=True,
            n_iter=1, 
            batch_size=0,
            learning_rate=0.1,
            do_animation=False,
            dataset='Wine',
            class_to_label=ds_scaled.class_to_label,
            show_fig=True,
            save_fig=True,
            random_state=RANDOM_STATE,
            show_anchors=False,
            supervised=False,
            show_points=True,
            show_inner_blobs=False,
            show_polygons=False,
            show_label_level_plots=True,
            show_anchor_level_plot=False,
            annotate_images=False,
            birch_threshold=0.4)
print(umap_scaled_amap)
# Out:
# AMAP
# =================
# addr:@1493c8
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=0.4
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=True
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=1
# magnitude_step=False
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x0000015A5C8868B8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.1
# mask_sparse_subcluster=None
# random_points_method='voronoi'
# class_to_label={0: 'class_0', 1: 'class_1', 2: 'class_2'}
# random_state=42
# n_jobs=None
# dataset='Wine'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=None
# douglas_peucker_tolerance=0.6
# smooth_iter=3
# skip_polygons_with_area=0.01
# mask_relation_in_same_label=True
# save_fig_every=1
# show_points=True
# show_anchors=False
# show_polygons=False
# show_inner_blobs=False
# show_label_level_plots=True
# show_anchor_level_plot=False
# every_matrix_in_single_plot=True
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# vmax_overlap=0.5
# vmax_proximity=0.5
# annotate_images=False
# k_annot_clf=40
# orig_images=None
# output_dir='../plots/Wine/2020-31-03_01-27-10/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# high_dim_proximity_matrix=None
# low_dim_proximity_matrix=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
low_dim_umap = umap_scaled_amap.fit_transform(X_scaled, y_scaled)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction all points
# Starting iteration 1 loss = 0.3157894736842105

# %% [markdown]
# # AMAP

# %% [markdown]
# ## Not Scaled

# %%
blobs_not_scaled_amap = AMAP(reduce_all_points=False,
                  n_iter=1, 
                  batch_size=0,
                  learning_rate=0.5,
                  dataset='Wine',
                  class_to_label=ds_not_scaled.class_to_label,
                  show_fig=True,
                  save_fig=True,
                  random_state=RANDOM_STATE,
                  show_anchors=False,
                  supervised=False,
                  show_points=False,
                  show_inner_blobs=False,
                  show_polygons=True,
                  show_label_level_plots=True,
                  show_anchor_level_plot=False,
                  save_fig_every=20,
                  annotate_images=False,
#                   birch_threshold=0.4,  # scaled features
                  birch_threshold=50,
                  alpha=0,
                  douglas_peucker_tolerance=0.1,
                  smooth_iter=3,
                  magnitude_step=True,
                  mask_sparse_subcluster=0,
                  top_greedy=3)
print(blobs_not_scaled_amap)
# Out:
# AMAP
# =================
# addr:@df548
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=50
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=False
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=3
# magnitude_step=True
# n_iter=1
# batch_size=0
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x0000015A5C8868B8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.5
# mask_sparse_subcluster=0
# random_points_method='voronoi'
# class_to_label={0: 'class_0', 1: 'class_1', 2: 'class_2'}
# random_state=42
# n_jobs=None
# dataset='Wine'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=0
# douglas_peucker_tolerance=0.1
# smooth_iter=3
# skip_polygons_with_area=0.01
# mask_relation_in_same_label=True
# save_fig_every=20
# show_points=False
# show_anchors=False
# show_polygons=True
# show_inner_blobs=False
# show_label_level_plots=True
# show_anchor_level_plot=False
# every_matrix_in_single_plot=True
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# vmax_overlap=0.5
# vmax_proximity=0.5
# annotate_images=False
# k_annot_clf=40
# orig_images=None
# output_dir='../plots/Wine/2020-31-03_01-30-42/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# high_dim_proximity_matrix=None
# low_dim_proximity_matrix=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
blobs_amap_low_dim = blobs_not_scaled_amap.fit_transform(X_not_scaled, y_not_scaled)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction only anchors
# Dim Reduction only anchors - generate random points in low dim per anchor
# 100%|███████████████████████████████████████████████████████████████████████████████| 197/197 [00:00<00:00, 424.79it/s]
# Starting iteration 1 loss = 0.4666666666666667

# %% [markdown]
# ## Scaled

# %%
blobs_amap = AMAP(reduce_all_points=False,
                  n_iter=41, 
                  batch_size=1,
                  learning_rate=0.5,
                  dataset='Wine',
                  class_to_label=ds_scaled.class_to_label,
                  show_fig=True,
                  save_fig=True,
                  random_state=RANDOM_STATE,
                  show_anchors=False,
                  supervised=False,
                  show_points=False,
                  show_inner_blobs=False,
                  show_polygons=True,
                  show_label_level_plots=True,
                  show_anchor_level_plot=False,
                  save_fig_every=40,
                  annotate_images=False,
                  birch_threshold=0.4,
                  alpha=0,
                  douglas_peucker_tolerance=0.1,
                  smooth_iter=3,
                  magnitude_step=True,
                  mask_sparse_subcluster=0,
                  top_greedy=3)
print(blobs_amap)
# Out:
# AMAP
# =================
# addr:@7c94c8
# verbose=True
# n_components=2
# anchors_method='birch'
# n_intra_anchors=None
# birch_threshold=0.4
# birch_branching_factor=None
# dim_reduction_algo='umap'
# supervised=False
# umap_n_neighbors=15
# umap_min_dist=1
# reduce_all_points=False
# uniform_points_per='anchor'
# k=20
# proximity_k=3
# self_relation=False
# radius_q=None
# do_relaxation=True
# top_greedy=3
# magnitude_step=True
# n_iter=41
# batch_size=1
# stop_criteria=1e-05
# loss_func=<function AMAP.l_inf_loss at 0x0000015A5C8868B8>
# loss='Linf'
# only_inter_relations=False
# learning_rate=0.5
# mask_sparse_subcluster=0
# random_points_method='voronoi'
# class_to_label={0: 'class_0', 1: 'class_1', 2: 'class_2'}
# random_state=42
# n_jobs=None
# dataset='Wine'
# show_fig=True
# save_fig=True
# is_plotly=False
# do_animation=False
# use_spline=False
# alpha=0
# douglas_peucker_tolerance=0.1
# smooth_iter=3
# skip_polygons_with_area=0.01
# mask_relation_in_same_label=True
# save_fig_every=40
# show_points=False
# show_anchors=False
# show_polygons=True
# show_inner_blobs=False
# show_label_level_plots=True
# show_anchor_level_plot=False
# every_matrix_in_single_plot=True
# main_plot_fig_size=(26, 13)
# show_anchors_annotation=False
# vmax_overlap=0.5
# vmax_proximity=0.5
# annotate_images=False
# k_annot_clf=40
# orig_images=None
# output_dir='../plots/Wine/2020-31-03_01-31-19/'
# num_clusters_each_label=[]
# X_with_centroids=None
# y_with_centroids=None
# clusters=None
# intra_class_anchors=None
# intra_class_anchors_labels=None
# intra_class_anchors_indices=None
# anchors_indices=None
# low_dim_anchors=None
# low_dim_points=None
# knng=None
# inter_class_relations=None
# inter_class_relations_low_dim=None
# inter_class_relations_label_level=None
# inter_class_relations_low_dim_label_level=None
# anchors_density=None
# anchors_radius=None
# losses=[]
# anchor_voronoi_regions=[]
# anchor_voronoi_regions_label=[]
# cand_samples_to_plot={}
# overlapped_anchor_per_label=None
# pure_anchor_per_label=None
# high_dim_proximity_matrix=None
# low_dim_proximity_matrix=None
# label_col='label'
# cluster_col='cluster'
# anchor_col='anchor'
# x_col='x'
# y_col='y'

# %%
low_sim_blobs = blobs_amap.fit_transform(X_scaled, y_scaled)
# Out:
# finding intra class anchors using birch
# UnSupervised Dim Reduction
# Dim Reduction only anchors
# Dim Reduction only anchors - generate random points in low dim per anchor
# 100%|███████████████████████████████████████████████████████████████████████████████| 207/207 [00:00<00:00, 605.11it/s]
# Starting iteration 1 loss = 0.5789473684210527
# src: 16 target 23 dir 1 density 1loss: 0.5789473684210527
# src: 9 target 0 dir 1 density 3loss: 0.35294117647058826
# src: 13 target 0 dir 1 density 1loss: 0.3157894736842105
# Starting iteration 2 loss = 0.5789473684210527
# src: 16 target 23 dir 1 density 1loss: 0.5789473684210527
# src: 9 target 0 dir 1 density 3loss: 0.35294117647058826
# src: 16 target 26 dir -1 density 1loss: -0.34210526315789475
# Starting iteration 3 loss = 0.5789473684210527
# src: 16 target 23 dir 1 density 1loss: 0.5789473684210527
# src: 16 target 26 dir -1 density 1loss: -0.4473684210526316
# src: 9 target 0 dir 1 density 3loss: 0.35294117647058826
# Starting iteration 4 loss = 0.553306342780027
# src: 16 target 23 dir 1 density 1loss: 0.553306342780027
# src: 16 target 26 dir -1 density 1loss: -0.5371120107962213
# src: 9 target 0 dir 1 density 3loss: 0.2647058823529412
# Starting iteration 5 loss = 0.5371120107962213
# src: 16 target 26 dir -1 density 1loss: -0.5371120107962213
# src: 16 target 23 dir 1 density 1loss: 0.45074224021592446
# src: 12 target 2 dir 1 density 1loss: 0.2631578947368421
# Starting iteration 6 loss = 0.48582995951417
# src: 16 target 26 dir -1 density 1loss: -0.48582995951417
# src: 16 target 23 dir 1 density 1loss: 0.2968960863697706
# src: 21 target 2 dir -1 density 2loss: -0.24074074074074076
# Starting iteration 7 loss = 0.43454790823211875
# src: 16 target 26 dir -1 density 1loss: -0.43454790823211875
# src: 21 target 2 dir -1 density 2loss: -0.25925925925925924
# src: 12 target 2 dir 1 density 1loss: 0.23684210526315788
# Starting iteration 8 loss = 0.43454790823211875
# src: 16 target 26 dir -1 density 1loss: -0.43454790823211875
# src: 21 target 2 dir -1 density 2loss: -0.25925925925925924
# src: 9 target 0 dir 1 density 3loss: 0.22058823529411767
# Starting iteration 9 loss = 0.43454790823211875
# src: 16 target 26 dir -1 density 1loss: -0.43454790823211875
# src: 21 target 2 dir -1 density 2loss: -0.25925925925925924
# src: 12 target 2 dir 1 density 1loss: 0.21052631578947367
# Starting iteration 10 loss = 0.3832658569500675
# src: 16 target 26 dir -1 density 1loss: -0.3832658569500675
# src: 21 target 2 dir -1 density 2loss: -0.24074074074074076
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 11 loss = 0.3576248313090418
# src: 16 target 26 dir -1 density 1loss: -0.3576248313090418
# src: 13 target 0 dir 1 density 1loss: 0.2631578947368421
# src: 21 target 2 dir -1 density 2loss: -0.24074074074074076
# Starting iteration 12 loss = 0.2807017543859649
# src: 16 target 26 dir -1 density 1loss: -0.2807017543859649
# src: 9 target 0 dir 1 density 3loss: 0.1911764705882353
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 13 loss = 0.22941970310391363
# src: 16 target 26 dir -1 density 1loss: -0.22941970310391363
# src: 9 target 0 dir 1 density 3loss: 0.2058823529411765
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 14 loss = 0.3157894736842105
# src: 13 target 0 dir 1 density 1loss: 0.3157894736842105
# src: 16 target 26 dir -1 density 1loss: -0.20377867746288797
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 15 loss = 0.2080136402387042
# src: 9 target 0 dir 1 density 3loss: 0.2080136402387042
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# src: 12 target 2 dir 1 density 1loss: 0.18421052631578946
# Starting iteration 16 loss = 0.23684210526315788
# src: 13 target 0 dir 1 density 1loss: 0.23684210526315788
# src: 9 target 0 dir 1 density 3loss: 0.2100840336134454
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 17 loss = 0.21052631578947367
# src: 12 target 2 dir 1 density 1loss: 0.21052631578947367
# src: 20 target 2 dir 1 density 1loss: 0.21052631578947367
# src: 13 target 0 dir 1 density 1loss: 0.21052631578947367
# Starting iteration 18 loss = 0.2100840336134454
# src: 9 target 0 dir 1 density 3loss: 0.2100840336134454
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# Starting iteration 19 loss = 0.21209610604805304
# src: 9 target 0 dir 1 density 3loss: 0.21209610604805304
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# src: 12 target 2 dir 1 density 1loss: 0.18421052631578946
# Starting iteration 20 loss = 0.21405228758169936
# src: 9 target 0 dir 1 density 3loss: 0.21405228758169936
# src: 13 target 0 dir 1 density 1loss: 0.21052631578947367
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 21 loss = 0.2631578947368421
# src: 12 target 0 dir 1 density 1loss: 0.2631578947368421
# src: 9 target 0 dir 1 density 3loss: 0.21595487510072525
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 22 loss = 0.2631578947368421
# src: 13 target 0 dir 1 density 1loss: 0.2631578947368421
# src: 9 target 0 dir 1 density 3loss: 0.21780604133545312
# src: 20 target 2 dir 1 density 1loss: 0.21052631578947367
# Starting iteration 23 loss = 0.21052631578947367
# src: 12 target 0 dir 1 density 1loss: 0.21052631578947367
# src: 9 target 0 dir 1 density 3loss: 0.2042925278219396
# src: 7 target 0 dir 1 density 22loss: 0.18867924528301888
# Starting iteration 24 loss = 0.21052631578947367
# src: 12 target 0 dir 1 density 1loss: 0.21052631578947367
# src: 9 target 0 dir 1 density 3loss: 0.2042925278219396
# src: 12 target 2 dir 1 density 1loss: 0.18421052631578946
# Starting iteration 25 loss = 0.1907790143084261
# src: 9 target 0 dir 1 density 3loss: 0.1907790143084261
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 7 target 0 dir 1 density 22loss: 0.1677002243039979
# Starting iteration 26 loss = 0.2042925278219396
# src: 9 target 0 dir 1 density 3loss: 0.2042925278219396
# src: 20 target 2 dir 1 density 1loss: 0.18421052631578946
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# Starting iteration 27 loss = 0.17708333333333334
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# src: 6 target 22 dir -1 density 5loss: -0.16666666666666666
# Starting iteration 28 loss = 0.2673611111111111
# src: 6 target 26 dir -1 density 5loss: -0.2673611111111111
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 29 loss = 0.23402777777777778
# src: 6 target 26 dir -1 density 5loss: -0.23402777777777778
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 30 loss = 0.21180555555555555
# src: 6 target 26 dir -1 density 5loss: -0.21180555555555555
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 31 loss = 0.17847222222222223
# src: 6 target 26 dir -1 density 5loss: -0.17847222222222223
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 32 loss = 0.18958333333333335
# src: 6 target 26 dir -1 density 5loss: -0.18958333333333335
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 33 loss = 0.17708333333333334
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# src: 6 target 26 dir -1 density 5loss: -0.16736111111111113
# Starting iteration 34 loss = 0.18958333333333335
# src: 6 target 26 dir -1 density 5loss: -0.18958333333333335
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 35 loss = 0.17847222222222223
# src: 6 target 26 dir -1 density 5loss: -0.17847222222222223
# src: 6 target 22 dir -1 density 5loss: -0.17777777777777778
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# Starting iteration 36 loss = 0.22291666666666668
# src: 6 target 26 dir -1 density 5loss: -0.22291666666666668
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 37 loss = 0.20069444444444445
# src: 6 target 26 dir -1 density 5loss: -0.20069444444444445
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 38 loss = 0.18958333333333335
# src: 6 target 26 dir -1 density 5loss: -0.18958333333333335
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 39 loss = 0.17847222222222223
# src: 6 target 26 dir -1 density 5loss: -0.17847222222222223
# src: 6 target 22 dir -1 density 5loss: -0.17777777777777778
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# Starting iteration 40 loss = 0.22291666666666668
# src: 6 target 26 dir -1 density 5loss: -0.22291666666666668
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666
# Starting iteration 41 loss = 0.18958333333333335
# src: 6 target 26 dir -1 density 5loss: -0.18958333333333335
# src: 6 target 23 dir 1 density 5loss: 0.17708333333333334
# src: 6 target 27 dir -1 density 5loss: -0.17291666666666666

# %%
pd.Series(y).value_counts().sort_index()
# Out:
# 0    59
# 1    71
# 2    48
# dtype: int64

# %%
blobs_amap.num_clusters_each_label, blobs_amap.num_clusters_each_label.sum()
# Out:
# (array([ 5, 17,  7], dtype=int64), 29)

# %%
# config for red with three classes
# blobs_amap.alpha = [0.75,0.5,0.5]
blobs_amap.alpha = [0,0,0]
blobs_amap.show_anchors = True
blobs_amap.show_polygons = True
blobs_amap.douglas_peucker_tolerance=0.1
blobs_amap.anchors_plot_sns_separate(1, True)
